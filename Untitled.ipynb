# %%
import numpy as np
import matplotlib.pyplot as plt
import

# %%
x, y = np.meshgrid(np.linspace(-1,1,100), np.linspace(-1,1,100))
d = np.sqrt(x*x+y*y)
sigma, mu = .5, 0.0
g = np.exp(-( (d-mu)**2 / ( 2.0 * sigma**2 ) ) )

# %%
plt.imshow(g, alpha=1)
rect = plt.Rectangle((25,25), 50, 50,fill='k', facecolor='k', alpha=.2)
ax = plt.gca()
ax.add_patch(rect)
